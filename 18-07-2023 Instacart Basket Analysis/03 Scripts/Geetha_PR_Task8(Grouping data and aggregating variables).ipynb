# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining path
path = r'C:\Users\Admin\Documents\18-07-2023 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
df_dept = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'))

# %%
df_dept
# Out:
#     Unnamed: 0       department
# 0            1           frozen
# 1            2            other
# 2            3           bakery
# 3            4          produce
# 4            5          alcohol
# 5            6    international
# 6            7        beverages
# 7            8             pets
# 8            9  dry goods pasta
# 9           10             bulk
# 10          11    personal care
# 11          12     meat seafood
# 12          13           pantry
# 13          14        breakfast
# 14          15     canned goods
# 15          16       dairy eggs
# 16          17        household
# 17          18           babies
# 18          19           snacks
# 19          20             deli
# 20          21          missing

# %%
# Inspect file
ords_prods_merge.shape
# Out:
# (30328763, 22)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             1   2398795        1    prior             2                   3
# 1             2    473747        1    prior             3                   3
# 2             3   2254736        1    prior             4                   4
# 3             4    431534        1    prior             5                   4
# 4             5   3367565        1    prior             6                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  7                   15.0         196                  1
# 1                 12                   21.0         196                  1
# 2                  7                   29.0         196                  1
# 3                 15                   28.0         196                  1
# 4                  7                   19.0         196                  1
#
#    ...  product_name  aisle_id department_id  prices  _merge  \
# 0  ...          Soda        77             7     9.0    both
# 1  ...          Soda        77             7     9.0    both
# 2  ...          Soda        77             7     9.0    both
# 3  ...          Soda        77             7     9.0    both
# 4  ...          Soda        77             7     9.0    both
#
#     price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0               NaN  Mid-range product  Regularly busy  Least busy days
# 1               NaN  Mid-range product  Regularly busy  Least busy days
# 2               NaN  Mid-range product      Least busy  Least busy days
# 3               NaN  Mid-range product      Least busy  Least busy days
# 4               NaN  Mid-range product  Regularly busy   Regularly busy
#
#   busiest_period_of_day
# 0        Average orders
# 1           Most orders
# 2        Average orders
# 3           Most orders
# 4        Average orders
#
# [5 rows x 22 columns]

# %%
ords_prods_merge.columns
# Out:
# Index(['Unnamed: 0_x', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'orders_day_of_week', 'order_hour_of_day', 'days_since_last_order',
#        'product_id', 'add_to_cart_order', 'reordered', 'Unnamed: 0_y',
#        'product_name', 'aisle_id', 'department_id', 'prices', '_merge',
#        ' price_range_loc', 'price_range_loc', 'busiest_day', 'busiest_days',
#        'busiest_period_of_day'],
#       dtype='object')

# %% [markdown]
# # Step1:  Find the mean orders for each department in the merged dataframe.¶

# %%
# Group by "product_name" 
ords_prods_merge.groupby('product_name')

# %%
ords_prods_merge
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                    1   2398795        1    prior             2
# 1                    2    473747        1    prior             3
# 2                    3   2254736        1    prior             4
# 3                    4    431534        1    prior             5
# 4                    5   3367565        1    prior             6
# ...                ...       ...      ...      ...           ...
# 30328758       3360494     31526   202557    prior            18
# 30328759       3376039   2745165   203436    prior             2
# 30328760       3388472    850996   204229    prior            12
# 30328761       3392718   2550789   204472    prior             6
# 30328762       3395727   2518919   204641    prior            10
#
#           orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                          3                  7                   15.0
# 1                          3                 12                   21.0
# 2                          4                  7                   29.0
# 3                          4                 15                   28.0
# 4                          2                  7                   19.0
# ...                      ...                ...                    ...
# 30328758                   5                 11                    3.0
# 30328759                   3                  5                   15.0
# 30328760                   2                  3                   25.0
# 30328761                   3                 15                    7.0
# 30328762                   2                 21                   11.0
#
#           product_id  add_to_cart_order  ...  \
# 0                196                  1  ...
# 1                196                  1  ...
# 2                196                  1  ...
# 3                196                  1  ...
# 4                196                  1  ...
# ...              ...                ...  ...
# 30328758       43553                  2  ...
# 30328759       42338                 16  ...
# 30328760       37595                 20  ...
# 30328761       37595                  9  ...
# 30328762       20543                 16  ...
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 30328758                              Orange Energy Shots        64
# 30328759                            Zucchini Chips, Pesto        50
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328762                                    Soleil Razors        55
#
#          department_id  prices  _merge   price_range_loc    price_range_loc  \
# 0                    7     9.0    both               NaN  Mid-range product
# 1                    7     9.0    both               NaN  Mid-range product
# 2                    7     9.0    both               NaN  Mid-range product
# 3                    7     9.0    both               NaN  Mid-range product
# 4                    7     9.0    both               NaN  Mid-range product
# ...                ...     ...     ...               ...                ...
# 30328758             7     3.7    both               NaN  Low-range product
# 30328759            19     6.9    both               NaN  Mid-range product
# 30328760            11    13.5    both               NaN  Mid-range product
# 30328761            11    13.5    both               NaN  Mid-range product
# 30328762            11     5.1    both               NaN  Mid-range product
#
#              busiest_day     busiest_days busiest_period_of_day
# 0         Regularly busy  Least busy days        Average orders
# 1         Regularly busy  Least busy days           Most orders
# 2             Least busy  Least busy days        Average orders
# 3             Least busy  Least busy days           Most orders
# 4         Regularly busy   Regularly busy        Average orders
# ...                  ...              ...                   ...
# 30328758  Regularly busy   Regularly busy           Most orders
# 30328759  Regularly busy  Least busy days         Fewest orders
# 30328760  Regularly busy   Regularly busy         Fewest orders
# 30328761  Regularly busy  Least busy days           Most orders
# 30328762  Regularly busy   Regularly busy        Average orders
#
# [30328763 rows x 22 columns]

# %%
# Split the data into groups by "department_id" and then calculate the mean for each "order_number" column
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# # Step 2: Create loyalty flag for existing customers.

# %%
# Group data by "user_id" column, generate maximum orders for each user, create "max_order column" for aggregation results
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check the data grouping for accuracy
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              1   2398795        1    prior             2
# 1              2    473747        1    prior             3
# 2              3   2254736        1    prior             4
# 3              4    431534        1    prior             5
# 4              5   3367565        1    prior             6
# 5              6    550135        1    prior             7
# 6              7   3108588        1    prior             8
# 7              8   2295261        1    prior             9
# 8              9   2550362        1    prior            10
# 9            144   2968173       15    prior            15
# 10           146   1870022       15    prior            17
# 11           147   1911383       15    prior            18
# 12           150   2715276       15    prior            21
# 13           151    487368       15    prior            22
# 14           209   2293453       19    prior             2
# 15           212   1973799       19    prior             5
# 16           214    532817       19    prior             7
# 17           232   1573906       21    prior            10
# 18           458   1593000       31    prior            10
# 19           465   2231262       31    prior            17
# 20           617   2580647       43    prior             6
# 21           620   2187180       43    prior             9
# 22           752   1318871       52    prior             2
# 23           753   1261384       52    prior             3
# 24           755    580568       52    prior             5
# 25           757   2428073       52    prior             7
# 26           759    342306       52    prior             9
# 27           760   1520353       52    prior            10
# 28           761   2542086       52    prior            11
# 29           762    944694       52    prior            12
# 30           765   1268191       52    prior            15
# 31           767   1122089       52    prior            17
# 32           768   1498922       52    prior            18
# 33           769    180919       52    prior            19
# 34           771   2695875       52    prior            21
# 35          1023    970922       67    prior             2
# 36          1024    596585       67    prior             3
# 37          1025   2037087       67    prior             4
# 38          1026   2474111       67    prior             5
# 39          1027   1568481       67    prior             6
# 40          1029   2048527       67    prior             8
# 41          1030   2389031       67    prior             9
# 42          1031   2378562       67    prior            10
# 43          1032   1515698       67    prior            11
# 44          1033   1928050       67    prior            12
# 45          1034   1949274       67    prior            13
# 46          1035    551869       67    prior            14
# 47          1037    768572       67    prior            16
# 48          1039    150528       67    prior            18
# 49          1040     29758       67    prior            19
# 50          1042   1558976       67    prior            21
# 51          1043    863974       67    prior            22
# 52          1044   2308399       67    prior            23
# 53          1202   2759128       81    prior             3
# 54          1204   1812985       81    prior             5
# 55          1210    499460       82    prior             3
# 56          1211   2728456       82    prior             4
# 57          1213   2653743       82    prior             6
# 58          1216   1358880       82    prior             9
# 59          1217    343588       82    prior            10
# 60          1222   3034663       82    prior            15
# 61          1225    147262       82    prior            18
# 62          1226   3144004       82    prior            19
# 63          1480   2126069       98    prior             3
# 64          1484   2210120       98    prior             7
# 65          1486    681011       98    prior             9
# 66          1488   2846344       98    prior            11
# 67          1489    747431       98    prior            12
# 68          1490   2383054       98    prior            13
# 69          1491   1993729       98    prior            14
# 70          1608   1403849      109    prior             3
# 71          1746   3273029      120    prior             3
# 72          2781   1861943      185    prior             2
# 73          2898   1680569      195    prior             8
# 74          2909    276171      195    prior            19
# 75          2912   2744976      195    prior            22
# 76          2915   2781919      195    prior            25
# 77          2921   1738718      195    prior            31
# 78          2924   3058369      195    prior            34
# 79          2927   1485596      195    prior            37
# 80          2930    417035      195    prior            40
# 81          2937   1615297      195    prior            47
# 82          2942   1765587      195    prior            52
# 83          2947    745908      195    prior            57
# 84          3451   2505656      222    prior            17
# 85          3472   3268370      222    prior            38
# 86          4667   2016711      290    prior             9
# 87          4686   2706088      290    prior            28
# 88          5551   1952286      331    prior             6
# 89          6137   1469869      377    prior             3
# 90          6259   1927023      387    prior             2
# 91          6740    858092      420    prior             4
# 92          6741    119314      420    prior             5
# 93          6794   1665683      423    prior             3
# 94          6810   3096825      423    prior            19
# 95          8791   1548901      546    prior             4
# 96          9333    668870      591    prior             2
# 97          9829   2483801      626    prior             2
# 98          9833   2741904      626    prior             6
# 99          9837   2138689      626    prior            10
#
#     orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                    3                  7                   15.0         196
# 1                    3                 12                   21.0         196
# 2                    4                  7                   29.0         196
# 3                    4                 15                   28.0         196
# 4                    2                  7                   19.0         196
# 5                    1                  9                   20.0         196
# 6                    1                 14                   14.0         196
# 7                    1                 16                    0.0         196
# 8                    4                  8                   30.0         196
# 9                    1                  9                    7.0         196
# 10                   2                 16                    8.0         196
# 11                   2                 11                    7.0         196
# 12                   1                  9                    7.0         196
# 13                   1                 10                   14.0         196
# 14                   5                 14                    6.0         196
# 15                   6                 12                    8.0         196
# 16                   4                 17                    6.0         196
# 17                   3                 10                    6.0         196
# 18                   3                  8                    7.0         196
# 19                   3                 11                    8.0         196
# 20                   4                 16                    4.0         196
# 21                   4                 12                    3.0         196
# 22                   1                 10                    7.0         196
# 23                   1                 10                    7.0         196
# 24                   2                 10                    8.0         196
# 25                   2                  7                    8.0         196
# 26                   1                 11                    7.0         196
# 27                   2                 10                    8.0         196
# 28                   2                  9                    7.0         196
# 29                   1                 16                    6.0         196
# 30                   2                 11                    8.0         196
# 31                   2                 10                    6.0         196
# 32                   2                 10                   14.0         196
# 33                   3                  8                    8.0         196
# 34                   5                 10                   30.0         196
# 35                   1                 15                    5.0         196
# 36                   1                 13                    7.0         196
# 37                   2                  9                    8.0         196
# 38                   3                 14                    8.0         196
# 39                   3                 12                    7.0         196
# 40                   2                 11                    7.0         196
# 41                   2                 14                    7.0         196
# 42                   1                 10                    6.0         196
# 43                   1                 11                    7.0         196
# 44                   2                 12                    8.0         196
# 45                   1                 10                    6.0         196
# 46                   1                  9                    7.0         196
# 47                   4                 10                    9.0         196
# 48                   5                 16                    4.0         196
# 49                   0                 14                    9.0         196
# 50                   1                  9                    5.0         196
# 51                   1                 11                   14.0         196
# 52                   1                 14                   14.0         196
# 53                   1                  9                   14.0         196
# 54                   2                 20                   30.0         196
# 55                   5                 10                    5.0         196
# 56                   0                 11                   16.0         196
# 57                   4                  9                   13.0         196
# 58                   1                 10                   30.0         196
# 59                   2                 11                    1.0         196
# 60                   2                 11                   12.0         196
# 61                   1                 13                    7.0         196
# 62                   2                 15                    8.0         196
# 63                   0                  9                   25.0         196
# 64                   5                 14                    5.0         196
# 65                   3                  9                   30.0         196
# 66                   4                 13                   15.0         196
# 67                   6                 13                   30.0         196
# 68                   4                 11                   30.0         196
# 69                   5                  8                    8.0         196
# 70                   3                 17                    9.0         196
# 71                   2                  8                   19.0         196
# 72                   1                 12                   25.0         196
# 73                   1                  9                    4.0         196
# 74                   5                 11                    3.0         196
# 75                   5                 10                    7.0         196
# 76                   1                 14                    4.0         196
# 77                   2                  8                    4.0         196
# 78                   3                 10                    6.0         196
# 79                   2                 15                    0.0         196
# 80                   3                 16                    2.0         196
# 81                   5                 10                    2.0         196
# 82                   3                 12                    2.0         196
# 83                   4                 11                    3.0         196
# 84                   2                 12                    1.0         196
# 85                   5                 15                    1.0         196
# 86                   5                 19                    6.0         196
# 87                   6                 10                    7.0         196
# 88                   5                 16                   30.0         196
# 89                   5                 17                    3.0         196
# 90                   4                 10                   22.0         196
# 91                   1                 19                   30.0         196
# 92                   3                 19                   16.0         196
# 93                   2                 11                    7.0         196
# 94                   2                 11                    7.0         196
# 95                   3                 18                   23.0         196
# 96                   1                 13                    7.0         196
# 97                   5                 15                    2.0         196
# 98                   1                 14                    5.0         196
# 99                   1                 10                    4.0         196
#
#     add_to_cart_order  ...  aisle_id  department_id prices  _merge  \
# 0                   1  ...        77              7    9.0    both
# 1                   1  ...        77              7    9.0    both
# 2                   1  ...        77              7    9.0    both
# 3                   1  ...        77              7    9.0    both
# 4                   1  ...        77              7    9.0    both
# 5                   1  ...        77              7    9.0    both
# 6                   2  ...        77              7    9.0    both
# 7                   4  ...        77              7    9.0    both
# 8                   1  ...        77              7    9.0    both
# 9                   2  ...        77              7    9.0    both
# 10                  6  ...        77              7    9.0    both
# 11                  1  ...        77              7    9.0    both
# 12                  1  ...        77              7    9.0    both
# 13                  1  ...        77              7    9.0    both
# 14                  3  ...        77              7    9.0    both
# 15                 15  ...        77              7    9.0    both
# 16                  1  ...        77              7    9.0    both
# 17                  2  ...        77              7    9.0    both
# 18                 17  ...        77              7    9.0    both
# 19                 14  ...        77              7    9.0    both
# 20                  9  ...        77              7    9.0    both
# 21                  1  ...        77              7    9.0    both
# 22                  5  ...        77              7    9.0    both
# 23                  3  ...        77              7    9.0    both
# 24                  6  ...        77              7    9.0    both
# 25                  5  ...        77              7    9.0    both
# 26                  5  ...        77              7    9.0    both
# 27                  4  ...        77              7    9.0    both
# 28                  3  ...        77              7    9.0    both
# 29                  7  ...        77              7    9.0    both
# 30                  3  ...        77              7    9.0    both
# 31                  4  ...        77              7    9.0    both
# 32                  6  ...        77              7    9.0    both
# 33                  4  ...        77              7    9.0    both
# 34                  1  ...        77              7    9.0    both
# 35                  2  ...        77              7    9.0    both
# 36                  2  ...        77              7    9.0    both
# 37                  1  ...        77              7    9.0    both
# 38                  2  ...        77              7    9.0    both
# 39                  2  ...        77              7    9.0    both
# 40                  1  ...        77              7    9.0    both
# 41                  1  ...        77              7    9.0    both
# 42                  1  ...        77              7    9.0    both
# 43                  1  ...        77              7    9.0    both
# 44                  1  ...        77              7    9.0    both
# 45                  1  ...        77              7    9.0    both
# 46                  1  ...        77              7    9.0    both
# 47                  1  ...        77              7    9.0    both
# 48                  1  ...        77              7    9.0    both
# 49                  2  ...        77              7    9.0    both
# 50                  2  ...        77              7    9.0    both
# 51                  3  ...        77              7    9.0    both
# 52                  1  ...        77              7    9.0    both
# 53                  2  ...        77              7    9.0    both
# 54                  1  ...        77              7    9.0    both
# 55                  2  ...        77              7    9.0    both
# 56                  1  ...        77              7    9.0    both
# 57                  5  ...        77              7    9.0    both
# 58                  1  ...        77              7    9.0    both
# 59                  1  ...        77              7    9.0    both
# 60                  1  ...        77              7    9.0    both
# 61                  1  ...        77              7    9.0    both
# 62                  1  ...        77              7    9.0    both
# 63                  7  ...        77              7    9.0    both
# 64                  1  ...        77              7    9.0    both
# 65                  1  ...        77              7    9.0    both
# 66                  2  ...        77              7    9.0    both
# 67                  4  ...        77              7    9.0    both
# 68                  1  ...        77              7    9.0    both
# 69                  2  ...        77              7    9.0    both
# 70                  5  ...        77              7    9.0    both
# 71                  2  ...        77              7    9.0    both
# 72                 10  ...        77              7    9.0    both
# 73                  2  ...        77              7    9.0    both
# 74                  2  ...        77              7    9.0    both
# 75                  2  ...        77              7    9.0    both
# 76                  1  ...        77              7    9.0    both
# 77                  2  ...        77              7    9.0    both
# 78                  2  ...        77              7    9.0    both
# 79                  2  ...        77              7    9.0    both
# 80                  2  ...        77              7    9.0    both
# 81                  2  ...        77              7    9.0    both
# 82                  3  ...        77              7    9.0    both
# 83                  3  ...        77              7    9.0    both
# 84                  2  ...        77              7    9.0    both
# 85                  6  ...        77              7    9.0    both
# 86                  8  ...        77              7    9.0    both
# 87                 16  ...        77              7    9.0    both
# 88                  8  ...        77              7    9.0    both
# 89                  9  ...        77              7    9.0    both
# 90                  3  ...        77              7    9.0    both
# 91                  2  ...        77              7    9.0    both
# 92                  2  ...        77              7    9.0    both
# 93                  3  ...        77              7    9.0    both
# 94                  2  ...        77              7    9.0    both
# 95                  1  ...        77              7    9.0    both
# 96                  1  ...        77              7    9.0    both
# 97                 10  ...        77              7    9.0    both
# 98                 12  ...        77              7    9.0    both
# 99                  5  ...        77              7    9.0    both
#
#      price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0                NaN  Mid-range product  Regularly busy  Least busy days
# 1                NaN  Mid-range product  Regularly busy  Least busy days
# 2                NaN  Mid-range product      Least busy  Least busy days
# 3                NaN  Mid-range product      Least busy  Least busy days
# 4                NaN  Mid-range product  Regularly busy   Regularly busy
# 5                NaN  Mid-range product  Regularly busy     Busiest days
# 6                NaN  Mid-range product  Regularly busy     Busiest days
# 7                NaN  Mid-range product  Regularly busy     Busiest days
# 8                NaN  Mid-range product      Least busy  Least busy days
# 9                NaN  Mid-range product  Regularly busy     Busiest days
# 10               NaN  Mid-range product  Regularly busy   Regularly busy
# 11               NaN  Mid-range product  Regularly busy   Regularly busy
# 12               NaN  Mid-range product  Regularly busy     Busiest days
# 13               NaN  Mid-range product  Regularly busy     Busiest days
# 14               NaN  Mid-range product  Regularly busy   Regularly busy
# 15               NaN  Mid-range product  Regularly busy   Regularly busy
# 16               NaN  Mid-range product      Least busy  Least busy days
# 17               NaN  Mid-range product  Regularly busy  Least busy days
# 18               NaN  Mid-range product  Regularly busy  Least busy days
# 19               NaN  Mid-range product  Regularly busy  Least busy days
# 20               NaN  Mid-range product      Least busy  Least busy days
# 21               NaN  Mid-range product      Least busy  Least busy days
# 75               NaN  Mid-range product  Regularly busy   Regularly busy
# 76               NaN  Mid-range product  Regularly busy     Busiest days
# 77               NaN  Mid-range product  Regularly busy   Regularly busy
# 78               NaN  Mid-range product  Regularly busy  Least busy days
# 79               NaN  Mid-range product  Regularly busy   Regularly busy
# 80               NaN  Mid-range product  Regularly busy  Least busy days
# 81               NaN  Mid-range product  Regularly busy   Regularly busy
# 82               NaN  Mid-range product  Regularly busy  Least busy days
# 83               NaN  Mid-range product      Least busy  Least busy days
# 84               NaN  Mid-range product  Regularly busy   Regularly busy
# 85               NaN  Mid-range product  Regularly busy   Regularly busy
# 86               NaN  Mid-range product  Regularly busy   Regularly busy
# 87               NaN  Mid-range product  Regularly busy   Regularly busy
# 88               NaN  Mid-range product  Regularly busy   Regularly busy
# 89               NaN  Mid-range product  Regularly busy   Regularly busy
# 90               NaN  Mid-range product      Least busy  Least busy days
# 91               NaN  Mid-range product  Regularly busy     Busiest days
# 92               NaN  Mid-range product  Regularly busy  Least busy days
# 93               NaN  Mid-range product  Regularly busy   Regularly busy
# 94               NaN  Mid-range product  Regularly busy   Regularly busy
# 95               NaN  Mid-range product  Regularly busy  Least busy days
# 96               NaN  Mid-range product  Regularly busy     Busiest days
# 97               NaN  Mid-range product  Regularly busy   Regularly busy
# 98               NaN  Mid-range product  Regularly busy     Busiest days
# 99               NaN  Mid-range product  Regularly busy     Busiest days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1            Most orders        10
# 2         Average orders        10
# 3            Most orders        10
# 4         Average orders        10
# 5            Most orders        10
# 6            Most orders        10
# 7            Most orders        10
# 8         Average orders        10
# 9            Most orders        22
# 10           Most orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13           Most orders        22
# 14           Most orders         9
# 15           Most orders         9
# 16        Average orders         9
# 17           Most orders        33
# 18        Average orders        20
# 19           Most orders        20
# 20           Most orders        11
# 21           Most orders        11
# 22           Most orders        27
# 23           Most orders        27
# 24           Most orders        27
# 25        Average orders        27
# 26           Most orders        27
# 27           Most orders        27
# 28           Most orders        27
# 29           Most orders        27
# 30           Most orders        27
# 31           Most orders        27
# 32           Most orders        27
# 33        Average orders        27
# 34           Most orders        27
# 35           Most orders        24
# 36           Most orders        24
# 37           Most orders        24
# 38           Most orders        24
# 39           Most orders        24
# 40           Most orders        24
# 41           Most orders        24
# 42           Most orders        24
# 43           Most orders        24
# 44           Most orders        24
# 45           Most orders        24
# 46           Most orders        24
# 47           Most orders        24
# 48           Most orders        24
# 49           Most orders        24
# 50           Most orders        24
# 51           Most orders        24
# 52           Most orders        24
# 53           Most orders         7
# 54        Average orders         7
# 55           Most orders        19
# 56           Most orders        19
# 57           Most orders        19
# 58           Most orders        19
# 59           Most orders        19
# 60           Most orders        19
# 61           Most orders        19
# 62           Most orders        19
# 63           Most orders        14
# 64           Most orders        14
# 65           Most orders        14
# 66           Most orders        14
# 67           Most orders        14
# 68           Most orders        14
# 69        Average orders        14
# 70        Average orders         6
# 71        Average orders         3
# 72           Most orders         6
# 73           Most orders        58
# 74           Most orders        58
# 75           Most orders        58
# 76           Most orders        58
# 77        Average orders        58
# 78           Most orders        58
# 79           Most orders        58
# 80           Most orders        58
# 81           Most orders        58
# 82           Most orders        58
# 83           Most orders        58
# 84           Most orders        70
# 85           Most orders        70
# 86        Average orders        51
# 87           Most orders        51
# 88           Most orders         8
# 89        Average orders         3
# 90           Most orders         8
# 91        Average orders        22
# 92        Average orders        22
# 93           Most orders        42
# 94           Most orders        42
# 95        Average orders         6
# 96           Most orders         7
# 97           Most orders        94
# 98           Most orders        94
# 99           Most orders        94
#
# [100 rows x 23 columns]

# %%
# Create flags to assign "loyalty" labels to user ID based on max order value
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequencies of loyalty flags for accuracy
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # Step 3: Find the mean of product prices by loyalty group.¶

# %%
# Group by "prices" 
ords_prods_merge.groupby('prices')

# %%
# Split the data into groups by "loyalty_flag" and then calculate the mean for each "prices" column
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.402162
# New customer      13.396333
# Regular customer  12.546842

# %% [markdown]
# # Step 4 : Create spending flag for each user based on average price of products across orders.

# %%
# Group data by "user_id" column, generate mean product price for each user, create "mean_price" for aggregation results
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check grouping
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              1   2398795        1    prior             2
# 1              2    473747        1    prior             3
# 2              3   2254736        1    prior             4
# 3              4    431534        1    prior             5
# 4              5   3367565        1    prior             6
# 5              6    550135        1    prior             7
# 6              7   3108588        1    prior             8
# 7              8   2295261        1    prior             9
# 8              9   2550362        1    prior            10
# 9            144   2968173       15    prior            15
# 10           146   1870022       15    prior            17
# 11           147   1911383       15    prior            18
# 12           150   2715276       15    prior            21
# 13           151    487368       15    prior            22
# 14           209   2293453       19    prior             2
# 15           212   1973799       19    prior             5
# 16           214    532817       19    prior             7
# 17           232   1573906       21    prior            10
# 18           458   1593000       31    prior            10
# 19           465   2231262       31    prior            17
# 20           617   2580647       43    prior             6
# 21           620   2187180       43    prior             9
# 22           752   1318871       52    prior             2
# 23           753   1261384       52    prior             3
# 24           755    580568       52    prior             5
# 25           757   2428073       52    prior             7
# 26           759    342306       52    prior             9
# 27           760   1520353       52    prior            10
# 28           761   2542086       52    prior            11
# 29           762    944694       52    prior            12
# 30           765   1268191       52    prior            15
# 31           767   1122089       52    prior            17
# 32           768   1498922       52    prior            18
# 33           769    180919       52    prior            19
# 34           771   2695875       52    prior            21
# 35          1023    970922       67    prior             2
# 36          1024    596585       67    prior             3
# 37          1025   2037087       67    prior             4
# 38          1026   2474111       67    prior             5
# 39          1027   1568481       67    prior             6
# 40          1029   2048527       67    prior             8
# 41          1030   2389031       67    prior             9
# 42          1031   2378562       67    prior            10
# 43          1032   1515698       67    prior            11
# 44          1033   1928050       67    prior            12
# 45          1034   1949274       67    prior            13
# 46          1035    551869       67    prior            14
# 47          1037    768572       67    prior            16
# 48          1039    150528       67    prior            18
# 49          1040     29758       67    prior            19
# 50          1042   1558976       67    prior            21
# 51          1043    863974       67    prior            22
# 52          1044   2308399       67    prior            23
# 53          1202   2759128       81    prior             3
# 54          1204   1812985       81    prior             5
# 55          1210    499460       82    prior             3
# 56          1211   2728456       82    prior             4
# 57          1213   2653743       82    prior             6
# 58          1216   1358880       82    prior             9
# 59          1217    343588       82    prior            10
# 60          1222   3034663       82    prior            15
# 61          1225    147262       82    prior            18
# 62          1226   3144004       82    prior            19
# 63          1480   2126069       98    prior             3
# 64          1484   2210120       98    prior             7
# 65          1486    681011       98    prior             9
# 66          1488   2846344       98    prior            11
# 67          1489    747431       98    prior            12
# 68          1490   2383054       98    prior            13
# 69          1491   1993729       98    prior            14
# 70          1608   1403849      109    prior             3
# 71          1746   3273029      120    prior             3
# 72          2781   1861943      185    prior             2
# 73          2898   1680569      195    prior             8
# 74          2909    276171      195    prior            19
# 75          2912   2744976      195    prior            22
# 76          2915   2781919      195    prior            25
# 77          2921   1738718      195    prior            31
# 78          2924   3058369      195    prior            34
# 79          2927   1485596      195    prior            37
# 80          2930    417035      195    prior            40
# 81          2937   1615297      195    prior            47
# 82          2942   1765587      195    prior            52
# 83          2947    745908      195    prior            57
# 84          3451   2505656      222    prior            17
# 85          3472   3268370      222    prior            38
# 86          4667   2016711      290    prior             9
# 87          4686   2706088      290    prior            28
# 88          5551   1952286      331    prior             6
# 89          6137   1469869      377    prior             3
# 90          6259   1927023      387    prior             2
# 91          6740    858092      420    prior             4
# 92          6741    119314      420    prior             5
# 93          6794   1665683      423    prior             3
# 94          6810   3096825      423    prior            19
# 95          8791   1548901      546    prior             4
# 96          9333    668870      591    prior             2
# 97          9829   2483801      626    prior             2
# 98          9833   2741904      626    prior             6
# 99          9837   2138689      626    prior            10
#
#     orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                    3                  7                   15.0         196
# 1                    3                 12                   21.0         196
# 2                    4                  7                   29.0         196
# 3                    4                 15                   28.0         196
# 4                    2                  7                   19.0         196
# 5                    1                  9                   20.0         196
# 6                    1                 14                   14.0         196
# 7                    1                 16                    0.0         196
# 8                    4                  8                   30.0         196
# 9                    1                  9                    7.0         196
# 10                   2                 16                    8.0         196
# 11                   2                 11                    7.0         196
# 12                   1                  9                    7.0         196
# 13                   1                 10                   14.0         196
# 14                   5                 14                    6.0         196
# 15                   6                 12                    8.0         196
# 16                   4                 17                    6.0         196
# 17                   3                 10                    6.0         196
# 18                   3                  8                    7.0         196
# 19                   3                 11                    8.0         196
# 20                   4                 16                    4.0         196
# 21                   4                 12                    3.0         196
# 22                   1                 10                    7.0         196
# 23                   1                 10                    7.0         196
# 24                   2                 10                    8.0         196
# 25                   2                  7                    8.0         196
# 26                   1                 11                    7.0         196
# 27                   2                 10                    8.0         196
# 28                   2                  9                    7.0         196
# 29                   1                 16                    6.0         196
# 30                   2                 11                    8.0         196
# 31                   2                 10                    6.0         196
# 32                   2                 10                   14.0         196
# 33                   3                  8                    8.0         196
# 34                   5                 10                   30.0         196
# 35                   1                 15                    5.0         196
# 36                   1                 13                    7.0         196
# 37                   2                  9                    8.0         196
# 38                   3                 14                    8.0         196
# 39                   3                 12                    7.0         196
# 40                   2                 11                    7.0         196
# 41                   2                 14                    7.0         196
# 42                   1                 10                    6.0         196
# 43                   1                 11                    7.0         196
# 44                   2                 12                    8.0         196
# 45                   1                 10                    6.0         196
# 46                   1                  9                    7.0         196
# 47                   4                 10                    9.0         196
# 48                   5                 16                    4.0         196
# 49                   0                 14                    9.0         196
# 50                   1                  9                    5.0         196
# 51                   1                 11                   14.0         196
# 52                   1                 14                   14.0         196
# 53                   1                  9                   14.0         196
# 54                   2                 20                   30.0         196
# 55                   5                 10                    5.0         196
# 56                   0                 11                   16.0         196
# 57                   4                  9                   13.0         196
# 58                   1                 10                   30.0         196
# 59                   2                 11                    1.0         196
# 60                   2                 11                   12.0         196
# 61                   1                 13                    7.0         196
# 62                   2                 15                    8.0         196
# 63                   0                  9                   25.0         196
# 64                   5                 14                    5.0         196
# 65                   3                  9                   30.0         196
# 66                   4                 13                   15.0         196
# 67                   6                 13                   30.0         196
# 68                   4                 11                   30.0         196
# 69                   5                  8                    8.0         196
# 70                   3                 17                    9.0         196
# 71                   2                  8                   19.0         196
# 72                   1                 12                   25.0         196
# 73                   1                  9                    4.0         196
# 74                   5                 11                    3.0         196
# 75                   5                 10                    7.0         196
# 76                   1                 14                    4.0         196
# 77                   2                  8                    4.0         196
# 78                   3                 10                    6.0         196
# 79                   2                 15                    0.0         196
# 80                   3                 16                    2.0         196
# 81                   5                 10                    2.0         196
# 82                   3                 12                    2.0         196
# 83                   4                 11                    3.0         196
# 84                   2                 12                    1.0         196
# 85                   5                 15                    1.0         196
# 86                   5                 19                    6.0         196
# 87                   6                 10                    7.0         196
# 88                   5                 16                   30.0         196
# 89                   5                 17                    3.0         196
# 90                   4                 10                   22.0         196
# 91                   1                 19                   30.0         196
# 92                   3                 19                   16.0         196
# 93                   2                 11                    7.0         196
# 94                   2                 11                    7.0         196
# 95                   3                 18                   23.0         196
# 96                   1                 13                    7.0         196
# 97                   5                 15                    2.0         196
# 98                   1                 14                    5.0         196
# 99                   1                 10                    4.0         196
#
#     add_to_cart_order  ...  prices  _merge  price_range_loc  \
# 0                   1  ...     9.0    both              NaN
# 1                   1  ...     9.0    both              NaN
# 2                   1  ...     9.0    both              NaN
# 3                   1  ...     9.0    both              NaN
# 4                   1  ...     9.0    both              NaN
# 5                   1  ...     9.0    both              NaN
# 6                   2  ...     9.0    both              NaN
# 7                   4  ...     9.0    both              NaN
# 8                   1  ...     9.0    both              NaN
# 9                   2  ...     9.0    both              NaN
# 10                  6  ...     9.0    both              NaN
# 11                  1  ...     9.0    both              NaN
# 12                  1  ...     9.0    both              NaN
# 13                  1  ...     9.0    both              NaN
# 14                  3  ...     9.0    both              NaN
# 15                 15  ...     9.0    both              NaN
# 16                  1  ...     9.0    both              NaN
# 17                  2  ...     9.0    both              NaN
# 18                 17  ...     9.0    both              NaN
# 19                 14  ...     9.0    both              NaN
# 20                  9  ...     9.0    both              NaN
# 21                  1  ...     9.0    both              NaN
# 22                  5  ...     9.0    both              NaN
# 23                  3  ...     9.0    both              NaN
# 24                  6  ...     9.0    both              NaN
# 25                  5  ...     9.0    both              NaN
# 26                  5  ...     9.0    both              NaN
# 27                  4  ...     9.0    both              NaN
# 28                  3  ...     9.0    both              NaN
# 29                  7  ...     9.0    both              NaN
# 30                  3  ...     9.0    both              NaN
# 31                  4  ...     9.0    both              NaN
# 32                  6  ...     9.0    both              NaN
# 33                  4  ...     9.0    both              NaN
# 34                  1  ...     9.0    both              NaN
# 35                  2  ...     9.0    both              NaN
# 36                  2  ...     9.0    both              NaN
# 37                  1  ...     9.0    both              NaN
# 38                  2  ...     9.0    both              NaN
# 39                  2  ...     9.0    both              NaN
# 40                  1  ...     9.0    both              NaN
# 41                  1  ...     9.0    both              NaN
# 42                  1  ...     9.0    both              NaN
# 43                  1  ...     9.0    both              NaN
# 44                  1  ...     9.0    both              NaN
# 45                  1  ...     9.0    both              NaN
# 46                  1  ...     9.0    both              NaN
# 47                  1  ...     9.0    both              NaN
# 48                  1  ...     9.0    both              NaN
# 49                  2  ...     9.0    both              NaN
# 50                  2  ...     9.0    both              NaN
# 51                  3  ...     9.0    both              NaN
# 52                  1  ...     9.0    both              NaN
# 53                  2  ...     9.0    both              NaN
# 54                  1  ...     9.0    both              NaN
# 55                  2  ...     9.0    both              NaN
# 56                  1  ...     9.0    both              NaN
# 57                  5  ...     9.0    both              NaN
# 58                  1  ...     9.0    both              NaN
# 59                  1  ...     9.0    both              NaN
# 60                  1  ...     9.0    both              NaN
# 61                  1  ...     9.0    both              NaN
# 62                  1  ...     9.0    both              NaN
# 63                  7  ...     9.0    both              NaN
# 64                  1  ...     9.0    both              NaN
# 65                  1  ...     9.0    both              NaN
# 66                  2  ...     9.0    both              NaN
# 67                  4  ...     9.0    both              NaN
# 68                  1  ...     9.0    both              NaN
# 69                  2  ...     9.0    both              NaN
# 70                  5  ...     9.0    both              NaN
# 71                  2  ...     9.0    both              NaN
# 72                 10  ...     9.0    both              NaN
# 73                  2  ...     9.0    both              NaN
# 74                  2  ...     9.0    both              NaN
# 75                  2  ...     9.0    both              NaN
# 76                  1  ...     9.0    both              NaN
# 77                  2  ...     9.0    both              NaN
# 78                  2  ...     9.0    both              NaN
# 79                  2  ...     9.0    both              NaN
# 80                  2  ...     9.0    both              NaN
# 81                  2  ...     9.0    both              NaN
# 82                  3  ...     9.0    both              NaN
# 83                  3  ...     9.0    both              NaN
# 84                  2  ...     9.0    both              NaN
# 85                  6  ...     9.0    both              NaN
# 86                  8  ...     9.0    both              NaN
# 87                 16  ...     9.0    both              NaN
# 88                  8  ...     9.0    both              NaN
# 89                  9  ...     9.0    both              NaN
# 90                  3  ...     9.0    both              NaN
# 91                  2  ...     9.0    both              NaN
# 92                  2  ...     9.0    both              NaN
# 93                  3  ...     9.0    both              NaN
# 94                  2  ...     9.0    both              NaN
# 95                  1  ...     9.0    both              NaN
# 96                  1  ...     9.0    both              NaN
# 97                 10  ...     9.0    both              NaN
# 98                 12  ...     9.0    both              NaN
# 99                  5  ...     9.0    both              NaN
#
#       price_range_loc     busiest_day     busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  
# 86        51    Loyal customer   7.263242
# 87        51    Loyal customer   7.263242
# 88         8      New customer   7.600000
# 89         3      New customer   8.344444
# 90         8      New customer   7.554167
# 91        22  Regular customer   7.468966
# 92        22  Regular customer   7.468966
# 93        42    Loyal customer   7.644444
# 94        42    Loyal customer   7.644444
# 95         6      New customer   7.788889
# 96         7      New customer   6.521429
# 97        94    Loyal customer   7.454193
# 98        94    Loyal customer   7.454193
# 99        94    Loyal customer   7.454193
#
# [100 rows x 25 columns]

# %%
# Create flags to assign "spending" labels to user ID based on mean product price
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check frequencies of spending flags for accuracy
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     29730505
# High spender      598258
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Step 5: Create order frequency flag that indicates users' ordering behaviour

# %%
# Group data by "user_id" column, generate median product of "days since prior order, create "median_days" for aggregation results
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
# Check grouping
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              1   2398795        1    prior             2
# 1              2    473747        1    prior             3
# 2              3   2254736        1    prior             4
# 3              4    431534        1    prior             5
# 4              5   3367565        1    prior             6
# 5              6    550135        1    prior             7
# 6              7   3108588        1    prior             8
# 7              8   2295261        1    prior             9
# 8              9   2550362        1    prior            10
# 9            144   2968173       15    prior            15
# 10           146   1870022       15    prior            17
# 11           147   1911383       15    prior            18
# 12           150   2715276       15    prior            21
# 13           151    487368       15    prior            22
# 14           209   2293453       19    prior             2
# 15           212   1973799       19    prior             5
# 16           214    532817       19    prior             7
# 17           232   1573906       21    prior            10
# 18           458   1593000       31    prior            10
# 19           465   2231262       31    prior            17
# 20           617   2580647       43    prior             6
# 21           620   2187180       43    prior             9
# 22           752   1318871       52    prior             2
# 23           753   1261384       52    prior             3
# 24           755    580568       52    prior             5
# 25           757   2428073       52    prior             7
# 26           759    342306       52    prior             9
# 27           760   1520353       52    prior            10
# 28           761   2542086       52    prior            11
# 29           762    944694       52    prior            12
# 30           765   1268191       52    prior            15
# 31           767   1122089       52    prior            17
# 32           768   1498922       52    prior            18
# 33           769    180919       52    prior            19
# 34           771   2695875       52    prior            21
# 35          1023    970922       67    prior             2
# 36          1024    596585       67    prior             3
# 37          1025   2037087       67    prior             4
# 38          1026   2474111       67    prior             5
# 39          1027   1568481       67    prior             6
# 40          1029   2048527       67    prior             8
# 41          1030   2389031       67    prior             9
# 42          1031   2378562       67    prior            10
# 43          1032   1515698       67    prior            11
# 44          1033   1928050       67    prior            12
# 45          1034   1949274       67    prior            13
# 46          1035    551869       67    prior            14
# 47          1037    768572       67    prior            16
# 48          1039    150528       67    prior            18
# 49          1040     29758       67    prior            19
# 50          1042   1558976       67    prior            21
# 51          1043    863974       67    prior            22
# 52          1044   2308399       67    prior            23
# 53          1202   2759128       81    prior             3
# 54          1204   1812985       81    prior             5
# 55          1210    499460       82    prior             3
# 56          1211   2728456       82    prior             4
# 57          1213   2653743       82    prior             6
# 58          1216   1358880       82    prior             9
# 59          1217    343588       82    prior            10
# 60          1222   3034663       82    prior            15
# 61          1225    147262       82    prior            18
# 62          1226   3144004       82    prior            19
# 63          1480   2126069       98    prior             3
# 64          1484   2210120       98    prior             7
# 65          1486    681011       98    prior             9
# 66          1488   2846344       98    prior            11
# 67          1489    747431       98    prior            12
# 68          1490   2383054       98    prior            13
# 69          1491   1993729       98    prior            14
# 70          1608   1403849      109    prior             3
# 71          1746   3273029      120    prior             3
# 72          2781   1861943      185    prior             2
# 73          2898   1680569      195    prior             8
# 74          2909    276171      195    prior            19
# 75          2912   2744976      195    prior            22
# 76          2915   2781919      195    prior            25
# 77          2921   1738718      195    prior            31
# 78          2924   3058369      195    prior            34
# 79          2927   1485596      195    prior            37
# 80          2930    417035      195    prior            40
# 81          2937   1615297      195    prior            47
# 82          2942   1765587      195    prior            52
# 83          2947    745908      195    prior            57
# 84          3451   2505656      222    prior            17
# 85          3472   3268370      222    prior            38
# 86          4667   2016711      290    prior             9
# 87          4686   2706088      290    prior            28
# 88          5551   1952286      331    prior             6
# 89          6137   1469869      377    prior             3
# 90          6259   1927023      387    prior             2
# 91          6740    858092      420    prior             4
# 92          6741    119314      420    prior             5
# 93          6794   1665683      423    prior             3
# 94          6810   3096825      423    prior            19
# 95          8791   1548901      546    prior             4
# 96          9333    668870      591    prior             2
# 97          9829   2483801      626    prior             2
# 98          9833   2741904      626    prior             6
# 99          9837   2138689      626    prior            10
#
#     orders_day_of_week  order_hour_of_day  days_since_last_order  product_id  \
# 0                    3                  7                   15.0         196
# 1                    3                 12                   21.0         196
# 2                    4                  7                   29.0         196
# 3                    4                 15                   28.0         196
# 4                    2                  7                   19.0         196
# 5                    1                  9                   20.0         196
# 6                    1                 14                   14.0         196
# 7                    1                 16                    0.0         196
# 8                    4                  8                   30.0         196
# 9                    1                  9                    7.0         196
# 10                   2                 16                    8.0         196
# 11                   2                 11                    7.0         196
# 12                   1                  9                    7.0         196
# 13                   1                 10                   14.0         196
# 14                   5                 14                    6.0         196
# 15                   6                 12                    8.0         196
# 16                   4                 17                    6.0         196
# 17                   3                 10                    6.0         196
# 18                   3                  8                    7.0         196
# 19                   3                 11                    8.0         196
# 20                   4                 16                    4.0         196
# 21                   4                 12                    3.0         196
# 22                   1                 10                    7.0         196
# 23                   1                 10                    7.0         196
# 24                   2                 10                    8.0         196
# 25                   2                  7                    8.0         196
# 26                   1                 11                    7.0         196
# 27                   2                 10                    8.0         196
# 28                   2                  9                    7.0         196
# 29                   1                 16                    6.0         196
# 30                   2                 11                    8.0         196
# 31                   2                 10                    6.0         196
# 32                   2                 10                   14.0         196
# 33                   3                  8                    8.0         196
# 34                   5                 10                   30.0         196
# 35                   1                 15                    5.0         196
# 36                   1                 13                    7.0         196
# 37                   2                  9                    8.0         196
# 38                   3                 14                    8.0         196
# 39                   3                 12                    7.0         196
# 40                   2                 11                    7.0         196
# 41                   2                 14                    7.0         196
# 42                   1                 10                    6.0         196
# 43                   1                 11                    7.0         196
# 44                   2                 12                    8.0         196
# 45                   1                 10                    6.0         196
# 46                   1                  9                    7.0         196
# 47                   4                 10                    9.0         196
# 48                   5                 16                    4.0         196
# 49                   0                 14                    9.0         196
# 50                   1                  9                    5.0         196
# 51                   1                 11                   14.0         196
# 52                   1                 14                   14.0         196
# 53                   1                  9                   14.0         196
# 54                   2                 20                   30.0         196
# 55                   5                 10                    5.0         196
# 56                   0                 11                   16.0         196
# 57                   4                  9                   13.0         196
# 58                   1                 10                   30.0         196
# 59                   2                 11                    1.0         196
# 60                   2                 11                   12.0         196
# 61                   1                 13                    7.0         196
# 62                   2                 15                    8.0         196
# 63                   0                  9                   25.0         196
# 64                   5                 14                    5.0         196
# 65                   3                  9                   30.0         196
# 66                   4                 13                   15.0         196
# 67                   6                 13                   30.0         196
# 68                   4                 11                   30.0         196
# 69                   5                  8                    8.0         196
# 70                   3                 17                    9.0         196
# 71                   2                  8                   19.0         196
# 72                   1                 12                   25.0         196
# 73                   1                  9                    4.0         196
# 74                   5                 11                    3.0         196
# 75                   5                 10                    7.0         196
# 76                   1                 14                    4.0         196
# 77                   2                  8                    4.0         196
# 78                   3                 10                    6.0         196
# 79                   2                 15                    0.0         196
# 80                   3                 16                    2.0         196
# 81                   5                 10                    2.0         196
# 82                   3                 12                    2.0         196
# 83                   4                 11                    3.0         196
# 84                   2                 12                    1.0         196
# 85                   5                 15                    1.0         196
# 86                   5                 19                    6.0         196
# 87                   6                 10                    7.0         196
# 88                   5                 16                   30.0         196
# 89                   5                 17                    3.0         196
# 90                   4                 10                   22.0         196
# 91                   1                 19                   30.0         196
# 92                   3                 19                   16.0         196
# 93                   2                 11                    7.0         196
# 94                   2                 11                    7.0         196
# 95                   3                 18                   23.0         196
# 96                   1                 13                    7.0         196
# 97                   5                 15                    2.0         196
# 98                   1                 14                    5.0         196
# 99                   1                 10                    4.0         196
#
#     add_to_cart_order  ...   price_range_loc    price_range_loc  \
# 0                   1  ...               NaN  Mid-range product
# 1                   1  ...               NaN  Mid-range product
# 2                   1  ...               NaN  Mid-range product
# 3                   1  ...               NaN  Mid-range product
# 4                   1  ...               NaN  Mid-range product
# 5                   1  ...               NaN  Mid-range product
# 6                   2  ...               NaN  Mid-range product
# 7                   4  ...               NaN  Mid-range product
# 8                   1  ...               NaN  Mid-range product
# 9                   2  ...               NaN  Mid-range product
# 10                  6  ...               NaN  Mid-range product
# 11                  1  ...               NaN  Mid-range product
# 12                  1  ...               NaN  Mid-range product
# 13                  1  ...               NaN  Mid-range product
# 14                  3  ...               NaN  Mid-range product
# 15                 15  ...               NaN  Mid-range product
# 16                  1  ...               NaN  Mid-range product
# 17                  2  ...               NaN  Mid-range product
# 18                 17  ...               NaN  Mid-range product
# 19                 14  ...               NaN  Mid-range product
# 20                  9  ...               NaN  Mid-range product
# 21                  1  ...               NaN  Mid-range product
# 22                  5  ...               NaN  Mid-range product
# 23                  3  ...               NaN  Mid-range product
# 20  Regular customer   7.323944   Low spender        10.0
# 21  Regular customer   7.323944   Low spender        10.0
# 22  Regular customer   6.330435   Low spender         8.0
# 23  Regular customer   6.330435   Low spender         8.0
# 24  Regular customer   6.330435   Low spender         8.0
# 25  Regular customer   6.330435   Low spender         8.0
# 26  Regular customer   6.330435   Low spender         8.0
# 27  Regular customer   6.330435   Low spender         8.0
# 28  Regular customer   6.330435   Low spender         8.0
# 29  Regular customer   6.330435   Low spender         8.0
# 30  Regular customer   6.330435   Low spender         8.0
# 31  Regular customer   6.330435   Low spender         8.0
# 32  Regular customer   6.330435   Low spender         8.0
# 33  Regular customer   6.330435   Low spender         8.0
# 34  Regular customer   6.330435   Low spender         8.0
# 35  Regular customer   7.635065   Low spender         7.0
# 36  Regular customer   7.635065   Low spender         7.0
# 37  Regular customer   7.635065   Low spender         7.0
# 38  Regular customer   7.635065   Low spender         7.0
# 39  Regular customer   7.635065   Low spender         7.0
# 40  Regular customer   7.635065   Low spender         7.0
# 41  Regular customer   7.635065   Low spender         7.0
# 42  Regular customer   7.635065   Low spender         7.0
# 43  Regular customer   7.635065   Low spender         7.0
# 44  Regular customer   7.635065   Low spender         7.0
# 45  Regular customer   7.635065   Low spender         7.0
# 46  Regular customer   7.635065   Low spender         7.0
# 47  Regular customer   7.635065   Low spender         7.0
# 48  Regular customer   7.635065   Low spender         7.0
# 49  Regular customer   7.635065   Low spender         7.0
# 50  Regular customer   7.635065   Low spender         7.0
# 51  Regular customer   7.635065   Low spender         7.0
# 52  Regular customer   7.635065   Low spender         7.0
# 53      New customer   7.800000   Low spender        30.0
# 54      New customer   7.800000   Low spender        30.0
# 55  Regular customer   6.270492   Low spender        11.5
# 56  Regular customer   6.270492   Low spender        11.5
# 57  Regular customer   6.270492   Low spender        11.5
# 58  Regular customer   6.270492   Low spender        11.5
# 59  Regular customer   6.270492   Low spender        11.5
# 60  Regular customer   6.270492   Low spender        11.5
# 61  Regular customer   6.270492   Low spender        11.5
# 62  Regular customer   6.270492   Low spender        11.5
# 63  Regular customer   7.763043   Low spender        25.0
# 64  Regular customer   7.763043   Low spender        25.0
# 65  Regular customer   7.763043   Low spender        25.0
# 66  Regular customer   7.763043   Low spender        25.0
# 67  Regular customer   7.763043   Low spender        25.0
# 68  Regular customer   7.763043   Low spender        25.0
# 69  Regular customer   7.763043   Low spender        25.0
# 70      New customer   6.135000   Low spender        26.0
# 71      New customer  10.050000  High spender        19.0
# 72      New customer   7.269444   Low spender        25.0
# 73    Loyal customer   7.105464   Low spender         4.0
# 74    Loyal customer   7.105464   Low spender         4.0
# 75    Loyal customer   7.105464   Low spender         4.0
# 76    Loyal customer   7.105464   Low spender         4.0
# 77    Loyal customer   7.105464   Low spender         4.0
# 78    Loyal customer   7.105464   Low spender         4.0
# 79    Loyal customer   7.105464   Low spender         4.0
# 80    Loyal customer   7.105464   Low spender         4.0
# 81    Loyal customer   7.105464   Low spender         4.0
# 82    Loyal customer   7.105464   Low spender         4.0
# 83    Loyal customer   7.105464   Low spender         4.0
# 84    Loyal customer   6.842204   Low spender         5.0
# 85    Loyal customer   6.842204   Low spender         5.0
# 86    Loyal customer   7.263242   Low spender         7.0
# 87    Loyal customer   7.263242   Low spender         7.0
# 88      New customer   7.600000   Low spender        30.0
# 89      New customer   8.344444   Low spender        16.5
# 90      New customer   7.554167   Low spender         8.0
# 91  Regular customer   7.468966   Low spender         7.0
# 92  Regular customer   7.468966   Low spender         7.0
# 93    Loyal customer   7.644444   Low spender         7.0
# 94    Loyal customer   7.644444   Low spender         7.0
# 95      New customer   7.788889   Low spender        30.0
# 96      New customer   6.521429   Low spender         2.0
# 97    Loyal customer   7.454193   Low spender         2.0
# 98    Loyal customer   7.454193   Low spender         2.0
# 99    Loyal customer   7.454193   Low spender         2.0
#
# [100 rows x 27 columns]

# %%
# Create flags to assign "freqency" labels to user ID based on median days since prior order
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days'] > 10) & (ords_prods_merge['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequencies of spending flags for accuracy
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             1   2398795        1    prior             2                   3
# 1             2    473747        1    prior             3                   3
# 2             3   2254736        1    prior             4                   4
# 3             4    431534        1    prior             5                   4
# 4             5   3367565        1    prior             6                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  7                   15.0         196                  1
# 1                 12                   21.0         196                  1
# 2                  7                   29.0         196                  1
# 3                 15                   28.0         196                  1
# 4                  7                   19.0         196                  1
#
#    ...    price_range_loc     busiest_day     busiest_days  \
# 0  ...  Mid-range product  Regularly busy  Least busy days
# 1  ...  Mid-range product  Regularly busy  Least busy days
# 2  ...  Mid-range product      Least busy  Least busy days
# 3  ...  Mid-range product      Least busy  Least busy days
# 4  ...  Mid-range product  Regularly busy   Regularly busy
#
#    busiest_period_of_day  max_order  loyalty_flag mean_price spending_flag  \
# 0         Average orders         10  New customer   6.372222   Low spender
# 1            Most orders         10  New customer   6.372222   Low spender
# 2         Average orders         10  New customer   6.372222   Low spender
# 3            Most orders         10  New customer   6.372222   Low spender
# 4         Average orders         10  New customer   6.372222   Low spender
#
#   median_days         frequency_flag
# 0        20.5  Non-frequent customer
# 1        20.5  Non-frequent customer
# 2        20.5  Non-frequent customer
# 3        20.5  Non-frequent customer
# 4        20.5  Non-frequent customer
#
# [5 rows x 28 columns]

# %%
# Examining the null values
print(ords_prods_merge[ords_prods_merge.frequency_flag.isnull()])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_last_order, product_id, add_to_cart_order, reordered, Unnamed: 0_y, product_name, aisle_id, department_id, prices, _merge,  price_range_loc, price_range_loc, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag, mean_price, spending_flag, median_days, frequency_flag]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# No null values

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated.pkl'))
