# %% [markdown]
# # Step1: Exercise follow through

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Dataframe

# %%
# Defining path
path = r'C:\Users\Admin\Documents\18-07-2023 Instacart Basket Analysis'

# %%
# Import ords_prods_merged
df_ords_prods_merged =  pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged.pkl'))

# %%
# Create subset of first 1M rows
df = df_ords_prods_merged[:1000000]

# %%
# Check shape
df.shape
# Out:
# (1000000, 17)

# %% [markdown]
# # If statements

# %%
#Define price label function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply price label on dataframe
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11496\2213225355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range']
# Out:
# 0         Mid-range product
# 1         Mid-range product
# 2         Mid-range product
# 3         Mid-range product
# 4         Mid-range product
#                 ...
# 999995    Mid-range product
# 999996    Mid-range product
# 999997    Mid-range product
# 999998    Mid-range product
# 999999    Mid-range product
# Name: price_range, Length: 1000000, dtype: object

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    631969
# Low-range product    368031
# Name: price_range, dtype: int64

# %%
# Check max price to confirm
df['prices'].max()
# Out:
# 14.0

# %%
df
# Out:
#         Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                  1   2398795        1    prior             2
# 1                  2    473747        1    prior             3
# 2                  3   2254736        1    prior             4
# 3                  4    431534        1    prior             5
# 4                  5   3367565        1    prior             6
# ...              ...       ...      ...      ...           ...
# 999995       3266452   2851346   196879    prior            12
# 999996       3266625   1119216   196894    prior             3
# 999997       3266723   3059661   196902    prior             5
# 999998       3266815   2904972   196910    prior             4
# 999999       3266818    682978   196910    prior             7
#
#         orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                        3                  7                   15.0
# 1                        3                 12                   21.0
# 2                        4                  7                   29.0
# 3                        4                 15                   28.0
# 4                        2                  7                   19.0
# ...                    ...                ...                    ...
# 999995                   0                 13                    6.0
# 999996                   1                 16                   30.0
# 999997                   6                 17                    6.0
# 999998                   5                  8                   10.0
# 999999                   1                  1                    9.0
#
#         product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0              196                  1          1           195
# 1              196                  1          1           195
# 2              196                  1          1           195
# 3              196                  1          1           195
# 4              196                  1          1           195
# ...            ...                ...        ...           ...
# 999995        7781                  4          0          7781
# 999996        7781                 14          0          7781
# 999997        7781                  2          0          7781
# 999998        7781                  6          0          7781
# 999999        7781                 10          1          7781
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 999995  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999996  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999997  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999998  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999999  Organic Sticks Low Moisture Part Skim Mozzarel...        21
#
#         department_id  prices _merge        price_range
# 0                   7     9.0   both  Mid-range product
# 1                   7     9.0   both  Mid-range product
# 2                   7     9.0   both  Mid-range product
# 3                   7     9.0   both  Mid-range product
# 4                   7     9.0   both  Mid-range product
# ...               ...     ...    ...                ...
# 999995             16     6.6   both  Mid-range product
# 999996             16     6.6   both  Mid-range product
# 999997             16     6.6   both  Mid-range product
# 999998             16     6.6   both  Mid-range product
# 999999             16     6.6   both  Mid-range product
#
# [1000000 rows x 18 columns]

# %% [markdown]
# # If-Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11496\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df
# Out:
#         Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                  1   2398795        1    prior             2
# 1                  2    473747        1    prior             3
# 2                  3   2254736        1    prior             4
# 3                  4    431534        1    prior             5
# 4                  5   3367565        1    prior             6
# ...              ...       ...      ...      ...           ...
# 999995       3266452   2851346   196879    prior            12
# 999996       3266625   1119216   196894    prior             3
# 999997       3266723   3059661   196902    prior             5
# 999998       3266815   2904972   196910    prior             4
# 999999       3266818    682978   196910    prior             7
#
#         orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                        3                  7                   15.0
# 1                        3                 12                   21.0
# 2                        4                  7                   29.0
# 3                        4                 15                   28.0
# 4                        2                  7                   19.0
# ...                    ...                ...                    ...
# 999995                   0                 13                    6.0
# 999996                   1                 16                   30.0
# 999997                   6                 17                    6.0
# 999998                   5                  8                   10.0
# 999999                   1                  1                    9.0
#
#         product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0              196                  1          1           195
# 1              196                  1          1           195
# 2              196                  1          1           195
# 3              196                  1          1           195
# 4              196                  1          1           195
# ...            ...                ...        ...           ...
# 999995        7781                  4          0          7781
# 999996        7781                 14          0          7781
# 999997        7781                  2          0          7781
# 999998        7781                  6          0          7781
# 999999        7781                 10          1          7781
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 999995  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999996  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999997  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999998  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999999  Organic Sticks Low Moisture Part Skim Mozzarel...        21
#
#         department_id  prices _merge        price_range price_range_loc
# 0                   7     9.0   both  Mid-range product             NaN
# 1                   7     9.0   both  Mid-range product             NaN
# 2                   7     9.0   both  Mid-range product             NaN
# 3                   7     9.0   both  Mid-range product             NaN
# 4                   7     9.0   both  Mid-range product             NaN
# ...               ...     ...    ...                ...             ...
# 999995             16     6.6   both  Mid-range product             NaN
# 999996             16     6.6   both  Mid-range product             NaN
# 999997             16     6.6   both  Mid-range product             NaN
# 999998             16     6.6   both  Mid-range product             NaN
# 999999             16     6.6   both  Mid-range product             NaN
#
# [1000000 rows x 19 columns]

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df
# Out:
#         Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                  1   2398795        1    prior             2
# 1                  2    473747        1    prior             3
# 2                  3   2254736        1    prior             4
# 3                  4    431534        1    prior             5
# 4                  5   3367565        1    prior             6
# ...              ...       ...      ...      ...           ...
# 999995       3266452   2851346   196879    prior            12
# 999996       3266625   1119216   196894    prior             3
# 999997       3266723   3059661   196902    prior             5
# 999998       3266815   2904972   196910    prior             4
# 999999       3266818    682978   196910    prior             7
#
#         orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                        3                  7                   15.0
# 1                        3                 12                   21.0
# 2                        4                  7                   29.0
# 3                        4                 15                   28.0
# 4                        2                  7                   19.0
# ...                    ...                ...                    ...
# 999995                   0                 13                    6.0
# 999996                   1                 16                   30.0
# 999997                   6                 17                    6.0
# 999998                   5                  8                   10.0
# 999999                   1                  1                    9.0
#
#         product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0              196                  1          1           195
# 1              196                  1          1           195
# 2              196                  1          1           195
# 3              196                  1          1           195
# 4              196                  1          1           195
# ...            ...                ...        ...           ...
# 999995        7781                  4          0          7781
# 999996        7781                 14          0          7781
# 999997        7781                  2          0          7781
# 999998        7781                  6          0          7781
# 999999        7781                 10          1          7781
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 999995  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999996  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999997  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999998  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999999  Organic Sticks Low Moisture Part Skim Mozzarel...        21
#
#         department_id  prices _merge        price_range    price_range_loc
# 0                   7     9.0   both  Mid-range product  Mid-range product
# 1                   7     9.0   both  Mid-range product  Mid-range product
# 2                   7     9.0   both  Mid-range product  Mid-range product
# 3                   7     9.0   both  Mid-range product  Mid-range product
# 4                   7     9.0   both  Mid-range product  Mid-range product
# ...               ...     ...    ...                ...                ...
# 999995             16     6.6   both  Mid-range product  Mid-range product
# 999996             16     6.6   both  Mid-range product  Mid-range product
# 999997             16     6.6   both  Mid-range product  Mid-range product
# 999998             16     6.6   both  Mid-range product  Mid-range product
# 999999             16     6.6   both  Mid-range product  Mid-range product
#
# [1000000 rows x 19 columns]

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df
# Out:
#         Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                  1   2398795        1    prior             2
# 1                  2    473747        1    prior             3
# 2                  3   2254736        1    prior             4
# 3                  4    431534        1    prior             5
# 4                  5   3367565        1    prior             6
# ...              ...       ...      ...      ...           ...
# 999995       3266452   2851346   196879    prior            12
# 999996       3266625   1119216   196894    prior             3
# 999997       3266723   3059661   196902    prior             5
# 999998       3266815   2904972   196910    prior             4
# 999999       3266818    682978   196910    prior             7
#
#         orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                        3                  7                   15.0
# 1                        3                 12                   21.0
# 2                        4                  7                   29.0
# 3                        4                 15                   28.0
# 4                        2                  7                   19.0
# ...                    ...                ...                    ...
# 999995                   0                 13                    6.0
# 999996                   1                 16                   30.0
# 999997                   6                 17                    6.0
# 999998                   5                  8                   10.0
# 999999                   1                  1                    9.0
#
#         product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0              196                  1          1           195
# 1              196                  1          1           195
# 2              196                  1          1           195
# 3              196                  1          1           195
# 4              196                  1          1           195
# ...            ...                ...        ...           ...
# 999995        7781                  4          0          7781
# 999996        7781                 14          0          7781
# 999997        7781                  2          0          7781
# 999998        7781                  6          0          7781
# 999999        7781                 10          1          7781
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 999995  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999996  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999997  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999998  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 999999  Organic Sticks Low Moisture Part Skim Mozzarel...        21
#
#         department_id  prices _merge        price_range    price_range_loc
# 0                   7     9.0   both  Mid-range product  Mid-range product
# 1                   7     9.0   both  Mid-range product  Mid-range product
# 2                   7     9.0   both  Mid-range product  Mid-range product
# 3                   7     9.0   both  Mid-range product  Mid-range product
# 4                   7     9.0   both  Mid-range product  Mid-range product
# ...               ...     ...    ...                ...                ...
# 999995             16     6.6   both  Mid-range product  Mid-range product
# 999996             16     6.6   both  Mid-range product  Mid-range product
# 999997             16     6.6   both  Mid-range product  Mid-range product
# 999998             16     6.6   both  Mid-range product  Mid-range product
# 999999             16     6.6   both  Mid-range product  Mid-range product
#
# [1000000 rows x 19 columns]

# %%
# Check value counts
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    631969
# Low-range product    368031
# Name: price_range_loc, dtype: int64

# %%
# Repeat process on entire dataframe
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, ' price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] < 5, 'price_range_loc'] = "Low-range product"

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                    1   2398795        1    prior             2
# 1                    2    473747        1    prior             3
# 2                    3   2254736        1    prior             4
# 3                    4    431534        1    prior             5
# 4                    5   3367565        1    prior             6
# ...                ...       ...      ...      ...           ...
# 30328758       3360494     31526   202557    prior            18
# 30328759       3376039   2745165   203436    prior             2
# 30328760       3388472    850996   204229    prior            12
# 30328761       3392718   2550789   204472    prior             6
# 30328762       3395727   2518919   204641    prior            10
#
#           orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                          3                  7                   15.0
# 1                          3                 12                   21.0
# 2                          4                  7                   29.0
# 3                          4                 15                   28.0
# 4                          2                  7                   19.0
# ...                      ...                ...                    ...
# 30328758                   5                 11                    3.0
# 30328759                   3                  5                   15.0
# 30328760                   2                  3                   25.0
# 30328761                   3                 15                    7.0
# 30328762                   2                 21                   11.0
#
#           product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0                196                  1          1           195
# 1                196                  1          1           195
# 2                196                  1          1           195
# 3                196                  1          1           195
# 4                196                  1          1           195
# ...              ...                ...        ...           ...
# 30328758       43553                  2          1         43557
# 30328759       42338                 16          1         42342
# 30328760       37595                 20          0         37599
# 30328761       37595                  9          0         37599
# 30328762       20543                 16          0         20544
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 30328758                              Orange Energy Shots        64
# 30328759                            Zucchini Chips, Pesto        50
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328762                                    Soleil Razors        55
#
#           department_id  prices _merge  price_range_loc    price_range_loc
# 0                     7     9.0   both              NaN  Mid-range product
# 1                     7     9.0   both              NaN  Mid-range product
# 2                     7     9.0   both              NaN  Mid-range product
# 3                     7     9.0   both              NaN  Mid-range product
# 4                     7     9.0   both              NaN  Mid-range product
# ...                 ...     ...    ...              ...                ...
# 30328758              7     3.7   both              NaN  Low-range product
# 30328759             19     6.9   both              NaN  Mid-range product
# 30328760             11    13.5   both              NaN  Mid-range product
# 30328761             11    13.5   both              NaN  Mid-range product
# 30328762             11     5.1   both              NaN  Mid-range product
#
# [30328763 rows x 19 columns]

# %% [markdown]
# # If statements with for loops

# %%
# Create new column in dataframe
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    5779087
# 1    5303718
# 6    4190948
# 5    3952326
# 2    3947564
# 3    3600589
# 4    3554531
# Name: orders_day_of_week, dtype: int64

# %%
# Set loop
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  ...]

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                    1   2398795        1    prior             2
# 1                    2    473747        1    prior             3
# 2                    3   2254736        1    prior             4
# 3                    4    431534        1    prior             5
# 4                    5   3367565        1    prior             6
# ...                ...       ...      ...      ...           ...
# 30328758       3360494     31526   202557    prior            18
# 30328759       3376039   2745165   203436    prior             2
# 30328760       3388472    850996   204229    prior            12
# 30328761       3392718   2550789   204472    prior             6
# 30328762       3395727   2518919   204641    prior            10
#
#           orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                          3                  7                   15.0
# 1                          3                 12                   21.0
# 2                          4                  7                   29.0
# 3                          4                 15                   28.0
# 4                          2                  7                   19.0
# ...                      ...                ...                    ...
# 30328758                   5                 11                    3.0
# 30328759                   3                  5                   15.0
# 30328760                   2                  3                   25.0
# 30328761                   3                 15                    7.0
# 30328762                   2                 21                   11.0
#
#           product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0                196                  1          1           195
# 1                196                  1          1           195
# 2                196                  1          1           195
# 3                196                  1          1           195
# 4                196                  1          1           195
# ...              ...                ...        ...           ...
# 30328758       43553                  2          1         43557
# 30328759       42338                 16          1         42342
# 30328760       37595                 20          0         37599
# 30328761       37595                  9          0         37599
# 30328762       20543                 16          0         20544
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 30328758                              Orange Energy Shots        64
# 30328759                            Zucchini Chips, Pesto        50
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328762                                    Soleil Razors        55
#
#           department_id  prices _merge  price_range_loc    price_range_loc
# 0                     7     9.0   both              NaN  Mid-range product
# 1                     7     9.0   both              NaN  Mid-range product
# 2                     7     9.0   both              NaN  Mid-range product
# 3                     7     9.0   both              NaN  Mid-range product
# 4                     7     9.0   both              NaN  Mid-range product
# ...                 ...     ...    ...              ...                ...
# 30328758              7     3.7   both              NaN  Low-range product
# 30328759             19     6.9   both              NaN  Mid-range product
# 30328760             11    13.5   both              NaN  Mid-range product
# 30328761             11    13.5   both              NaN  Mid-range product
# 30328762             11     5.1   both              NaN  Mid-range product
#
# [30328763 rows x 19 columns]

# %%
# Add result to dataframe
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                    1   2398795        1    prior             2
# 1                    2    473747        1    prior             3
# 2                    3   2254736        1    prior             4
# 3                    4    431534        1    prior             5
# 4                    5   3367565        1    prior             6
# ...                ...       ...      ...      ...           ...
# 30328758       3360494     31526   202557    prior            18
# 30328759       3376039   2745165   203436    prior             2
# 30328760       3388472    850996   204229    prior            12
# 30328761       3392718   2550789   204472    prior             6
# 30328762       3395727   2518919   204641    prior            10
#
#           orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                          3                  7                   15.0
# 1                          3                 12                   21.0
# 2                          4                  7                   29.0
# 3                          4                 15                   28.0
# 4                          2                  7                   19.0
# ...                      ...                ...                    ...
# 30328758                   5                 11                    3.0
# 30328759                   3                  5                   15.0
# 30328760                   2                  3                   25.0
# 30328761                   3                 15                    7.0
# 30328762                   2                 21                   11.0
#
#           product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0                196                  1          1           195
# 1                196                  1          1           195
# 2                196                  1          1           195
# 3                196                  1          1           195
# 4                196                  1          1           195
# ...              ...                ...        ...           ...
# 30328758       43553                  2          1         43557
# 30328759       42338                 16          1         42342
# 30328760       37595                 20          0         37599
# 30328761       37595                  9          0         37599
# 30328762       20543                 16          0         20544
#
#                                              product_name  aisle_id  \
# 0                                                    Soda        77
# 1                                                    Soda        77
# 2                                                    Soda        77
# 3                                                    Soda        77
# 4                                                    Soda        77
# ...                                                   ...       ...
# 30328758                              Orange Energy Shots        64
# 30328759                            Zucchini Chips, Pesto        50
# 30328760  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328761  Dead Sea Minerals Eucalyptus Triple Milled Soap        25
# 30328762                                    Soleil Razors        55
#
#           department_id  prices _merge  price_range_loc    price_range_loc  \
# 0                     7     9.0   both              NaN  Mid-range product
# 1                     7     9.0   both              NaN  Mid-range product
# 2                     7     9.0   both              NaN  Mid-range product
# 3                     7     9.0   both              NaN  Mid-range product
# 4                     7     9.0   both              NaN  Mid-range product
# ...                 ...     ...    ...              ...                ...
# 30328758              7     3.7   both              NaN  Low-range product
# 30328759             19     6.9   both              NaN  Mid-range product
# 30328760             11    13.5   both              NaN  Mid-range product
# 30328761             11    13.5   both              NaN  Mid-range product
# 30328762             11     5.1   both              NaN  Mid-range product
#
#              busiest_day
# 0         Regularly busy
# 1         Regularly busy
# 2             Least busy
# 3             Least busy
# 4         Regularly busy
# ...                  ...
# 30328758  Regularly busy
# 30328759  Regularly busy
# 30328760  Regularly busy
# 30328761  Regularly busy
# 30328762  Regularly busy
#
# [30328763 rows x 20 columns]

# %%
# Check value counts
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    20995145
# Busiest day        5779087
# Least busy         3554531
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Step2: new column for busiest days

# %%
# Create new if-statement for-loop for new requirements
result_v2 = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_v2.append("Busiest days")
  elif value == 4 or value == 3:
    result_v2.append("Least busy days")
  else:
    result_v2.append("Regularly busy")

# %%
# Add result to dataframe in new column
df_ords_prods_merged['busiest_days'] = result_v2

# %%
# Check
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             1   2398795        1    prior             2                   3
# 1             2    473747        1    prior             3                   3
# 2             3   2254736        1    prior             4                   4
# 3             4    431534        1    prior             5                   4
# 4             5   3367565        1    prior             6                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  7                   15.0         196                  1
# 1                 12                   21.0         196                  1
# 2                  7                   29.0         196                  1
# 3                 15                   28.0         196                  1
# 4                  7                   19.0         196                  1
#
#    ...  Unnamed: 0_y  product_name aisle_id  department_id  prices  _merge  \
# 0  ...           195          Soda       77              7     9.0    both
# 1  ...           195          Soda       77              7     9.0    both
# 2  ...           195          Soda       77              7     9.0    both
# 3  ...           195          Soda       77              7     9.0    both
# 4  ...           195          Soda       77              7     9.0    both
#
#    price_range_loc    price_range_loc     busiest_day     busiest_days
# 0              NaN  Mid-range product  Regularly busy  Least busy days
# 1              NaN  Mid-range product  Regularly busy  Least busy days
# 2              NaN  Mid-range product      Least busy  Least busy days
# 3              NaN  Mid-range product      Least busy  Least busy days
# 4              NaN  Mid-range product  Regularly busy   Regularly busy
#
# [5 rows x 21 columns]

# %% [markdown]
# # Step3: Value of the busiest days

# %%
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12090838
# Busiest days       11082805
# Least busy days     7155120
# Name: busiest_days, dtype: int64

# %% [markdown]
# # when checked with original frequency, these 'busiest days' values calculates if value 0 or 1 then busiest days and if value 3 or 4 then least busy days.

# %% [markdown]
# # Step4: Creating busiest period of the day column

# %%
# Check frequency of values in the "order_hour_of_day" column 
df_ords_prods_merged['order_hour_of_day'].value_counts()
# Out:
# 10    2593725
# 11    2564597
# 14    2517238
# 15    2487586
# 13    2487500
# 12    2445841
# 16    2364969
# 9     2311334
# 17    1943858
# 8     1622394
# 18    1520954
# 19    1169224
# 20     910005
# 7      844665
# 21     746254
# 22     592432
# 23     375889
# 6      274801
# 0      203460
# 1      108110
# 5       82706
# 2       63961
# 4       49400
# 3       47860
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# # As the client wants these grouped into three different segments, we can group the 24 hours of the day as follows: Most orders = 10, 11, 14, 15, 13, 12, 16, 9; Average orders = 17, 8, 18, 19, 20, 7, 21, 22; Fewest orders = 23, 6, 0, 1, 5, 2, 4, 3¶

# %%
# Create a for-loop if statement using the above breakdown
hour_of_day = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
df_ords_prods_merged['busiest_period_of_day'] = hour_of_day

# %%
# Check
df_ords_prods_merged[['order_hour_of_day', 'busiest_period_of_day']].head(10)
# Out:
#    order_hour_of_day busiest_period_of_day
# 0                  7        Average orders
# 1                 12           Most orders
# 2                  7        Average orders
# 3                 15           Most orders
# 4                  7        Average orders
# 5                  9           Most orders
# 6                 14           Most orders
# 7                 16           Most orders
# 8                  8        Average orders
# 9                  9           Most orders

# %% [markdown]
# # Step 5: Print Frequency

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# Most orders       19772790
# Average orders     9349786
# Fewest orders      1206187
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# These frequencies match the sums of the above "ungrouped" frequencies, confirming the correct application of the labels¶

# %% [markdown]
# # Step7: Export dataframe as a pickle file

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated.pkl'))
